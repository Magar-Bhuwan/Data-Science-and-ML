# %%
print("Hello World")
# Out:
# Hello World

# %%
import tensorflow as tf
import numpy as np

# Data
X = np.array([[0], [1], [2], [3], [4], [5]], dtype=float)
y = np.array([0, 0, 0, 1, 1, 1], dtype=float)

# Model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.fit(X, y, epochs=300, verbose=0)

print(model.predict([[2.5]]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 17
#      13 model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#      14
#      15 model.fit(X, y, epochs=300, verbose=0)
#      16
# ---> 17 print(model.predict([[2.5]]))
#
# File d:\ML with Python\Data Seience and ML\COURSE\2_Data_Science_ML\.env\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File d:\ML with Python\Data Seience and ML\COURSE\2_Data_Science_ML\.env\Lib\site-packages\keras\src\trainers\data_adapters\__init__.py:163, in get_data_adapter(x, y, sample_weight, batch_size, steps_per_epoch, shuffle, class_weight)
#     155     return GeneratorDataAdapter(x)
#     156     # TODO: should we warn or not?
#     157     # warnings.warn(
#     158     #     "`shuffle=True` was passed, but will be ignored since the "
#    (...)    161     # )
#     162 else:
# --> 163     raise ValueError(f"Unrecognized data type: x={x} (of type {type(x)})")
#
# ValueError: Unrecognized data type: x=[[2.5]] (of type <class 'list'>)
