# %%
print("Welcome to the Data Science and Machine Learning")

# %%
print("This is a beginner-friendly course that will introduce you to the fundamentals of data science and machine learning. We will cover topics such as data analysis, data visualization, and machine learning algorithms. By the end of this course, you will have a solid understanding of the basics of data science and machine learning, and you will be able to apply these concepts to real-world problems. Let's get started!")
